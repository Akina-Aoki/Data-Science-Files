# %% [markdown]
# # Data Wrangling
# First Documentation about Introduction to Data Wrangling link: http://localhost:8888/notebooks/Data%20Wrangling%20Introduction.ipynb
#
#
# # Objectives
# - Identify and Handle Possible Missing Values
# - Prepare Countries DataFrame For Analysis
# - Grouping Data Based On Currency Basis
# - Streamline Analysis For Specific Countries' Currencies
# - Use Descriptive Statistics to Gain Basic Insight of Data
# - Combine cleaned datasets into one DataFrame
# - Export DataFrame from Jupyter Notebook

# %% [markdown]
# # BigMac Dataset
# This is the link for the Bigmac Dataset.
# https://www.kaggle.com/datasets/vittoriogiatti/bigmacprice/data
#
# ### Mcdonalds' Bigmac price for every country in the world from 2000 to 2022.
#
#
# # Extracting the Dataset from Kaggle
# Extracting data online by downloading a dataset from kaggle, and saving into a csv file into my computer.
#
# What to do when ecountering **SyntaxError: (unicode error)**
#
# - **Copied path from excel file**
# file path = <code>"C:\Users-----\Documents\---\All Python Files\Kaggle Data Sets\BigmacPrice.csv"</code>
#
# Then, copy the file path of the downloaded dataset in csv form and convert in the following:
# - **raw string literal**
# file_path = <code>r'C:\Users-----\Documents\---\All Python Files\Kaggle Data Sets\BigmacPrice.csv'</code>
#
# or
# - **escaping backslashes**
# file_path = <code>'C:\Users\-----\Documents\---\All Python Files\Kaggle Data Sets\BigmacPrice.csv'</code>

# %% [markdown]
# # Import Libraries
#
# About %matplotlib inline A command used in Jupyter Notebook to tell it to display plots directly within the notebook itself right below the code cell created rather than in a separate window or file.
#
# import requests In able for Line 4 to be successful and resolve the NameError

# %% [markdown]
# If you're running the code within a Jupyter Notebook and if you haven't already installed the **requests library**, you will indeed need to install it using <code>pip install requests</code> in your terminal or command prompt.
#
# After executing this command, you should be able to import and use the requests library in your notebook. Then, you can proceed with the rest of the code to download the dataset.
#
# This code will download the dataset from the provided URL and save it with the specified filename in the current directory. You can then use <code>pandas.read_csv()</code> to read the CSV file into a DataFrame as usual.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\jocke\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jocke\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jocke\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jocke\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jocke\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %% [markdown]
# # Read CSV file into Pandas DataFrame
#
# Here, name the dataframe as **bigmac_df**

# %% [markdown]
# ### header = 0 explanation
# file_path = ''
# <code>df = pd.read_csv(file_path, header = 0)</code>
#
# When you read a CSV file into a DataFrame using <code>pd.read_csv()</code> in pandas, the header parameter determines which row in the CSV file is considered as the header, i.e., the row that contains the column names.
#
# Use <code>header=0</code> when you are sure that the first row of the CSV file contains the column names. It is a good practice for clarity and explicitness in your code.

# %%
# Define the file path to your CSV file
file_path = r"C:\Users\jocke\Documents\Aira\All Python Files\Kaggle Data Sets\Bigmac Dataset.csv"

# %%
# Read the CSV file into a DataFrame called "bigmac_df"
bigmac_df = pd.read_csv(file_path, header = 0)

# Display the first few rows of the DataFrame to check if the data is imported correctly
bigmac_df.head()
# Out:
#          date currency_code       name  local_price  dollar_ex  dollar_price
# 0  2000-04-01           ARS  Argentina         2.50          1          2.50
# 1  2000-04-01           AUD  Australia         2.59          1          2.59
# 2  2000-04-01           BRL     Brazil         2.95          1          2.95
# 3  2000-04-01           GBP    Britain         1.90          1          1.90
# 4  2000-04-01           CAD     Canada         2.85          1          2.85

# %%
# Display the last few rows of the DataFrame
bigmac_df.tail()
# Out:
#             date currency_code                  name  local_price  dollar_ex  \
# 1941  2022-07-01           AED  United Arab Emirates        18.00          3
# 1942  2022-07-01           USD         United States         5.15          1
# 1943  2022-07-01           UYU               Uruguay       255.00         41
# 1944  2022-07-01           VES             Venezuela        10.00          5
# 1945  2022-07-01           VND               Vietnam     69000.00      23417
#
#       dollar_price
# 1941          6.00
# 1942          5.15
# 1943          6.22
# 1944          2.00
# 1945          2.95

# %% [markdown]
# ## Verify DataFrame Loading
#
# Verify loading by displaying the dataframe summary using <code>df.info()</code>

# %%
bigmac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1946 non-null   object
#  1   currency_code  1946 non-null   object
#  2   name           1946 non-null   object
#  3   local_price    1946 non-null   float64
#  4   dollar_ex      1946 non-null   int64
#  5   dollar_price   1946 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 91.3+ KB

# %% [markdown]
# ### Insight from .info() result
#
# Read carefully the data types for each column as shown above. There are 1946 rows(entries) and within all those entries, result shows that:
#
# A **non-null** values are those that do have data recorded. They are not empty or missing.
#
# A **null-value** typically represents missing or empty data.
#
# **Non-null count** The output indicates that each column in the dataset has 1946 non-null values. This means that there are no missing or empty values (null values) in any of the columns.
#
# ### Data types
#
# The data types also seem appropriate for their columns, so there is no need to convert the data types from this dataset.

# %% [markdown]
# ### Round up local_price
#
# **np.round()**
# Update and round to nearest 2 decimal places the <code>local_price</code> column. Keep an eye of how <code>local_price</code> column changes.

# %%
bigmac_df[['local_price']] = np.round(bigmac_df[['local_price']], 2)
display(bigmac_df)
# Out:
#             date currency_code                  name  local_price  dollar_ex  \
# 0     2000-04-01           ARS             Argentina         2.50          1
# 1     2000-04-01           AUD             Australia         2.59          1
# 2     2000-04-01           BRL                Brazil         2.95          1
# 3     2000-04-01           GBP               Britain         1.90          1
# 4     2000-04-01           CAD                Canada         2.85          1
# ...          ...           ...                   ...          ...        ...
# 1941  2022-07-01           AED  United Arab Emirates        18.00          3
# 1942  2022-07-01           USD         United States         5.15          1
# 1943  2022-07-01           UYU               Uruguay       255.00         41
# 1944  2022-07-01           VES             Venezuela        10.00          5
# 1945  2022-07-01           VND               Vietnam     69000.00      23417
#
#       dollar_price
# 0             2.50
# 1             2.59
# 2             2.95
# 3             1.90
# 4             2.85
# ...            ...
# 1941          6.00
# 1942          5.15
# 1943          6.22
# 1944          2.00
# 1945          2.95
#
# [1946 rows x 6 columns]

# %% [markdown]
# ### Rename a column
#
# **rename(columns = {'old', 'new'})**
#
# Change the <code>name</code> column to <code>country</code> column.
#
# <code>inplace=True</code> This parameter ensures that the changes are made directly to the original DataFrame.

# %%
bigmac_df.rename(columns={'name': 'country'}, inplace=True)
bigmac_df
# Out:
#             date currency_code               country  local_price  dollar_ex  \
# 0     2000-04-01           ARS             Argentina         2.50          1
# 1     2000-04-01           AUD             Australia         2.59          1
# 2     2000-04-01           BRL                Brazil         2.95          1
# 3     2000-04-01           GBP               Britain         1.90          1
# 4     2000-04-01           CAD                Canada         2.85          1
# ...          ...           ...                   ...          ...        ...
# 1941  2022-07-01           AED  United Arab Emirates        18.00          3
# 1942  2022-07-01           USD         United States         5.15          1
# 1943  2022-07-01           UYU               Uruguay       255.00         41
# 1944  2022-07-01           VES             Venezuela        10.00          5
# 1945  2022-07-01           VND               Vietnam     69000.00      23417
#
#       dollar_price
# 0             2.50
# 1             2.59
# 2             2.95
# 3             1.90
# 4             2.85
# ...            ...
# 1941          6.00
# 1942          5.15
# 1943          6.22
# 1944          2.00
# 1945          2.95
#
# [1946 rows x 6 columns]

# %% [markdown]
# # Identifying and Handling Missing Values
#
# ## Check the dataset for missing values(per column, entire dataframe, or for loop)
#
# Even though the <code>.info()</code> already showed that there are 0 null-values, it is still good practice to identify for possibe missing values.
#
# ## per column
#
# <code>x = df.isnull().sum()</code> This will give the count of NaN values in each column of the DataFrame.

# %%
# Check for missing values per column 
missing_per_column = bigmac_df.isnull().sum()
missing_per_column
# Out:
# date             0
# currency_code    0
# country          0
# local_price      0
# dollar_ex        0
# dollar_price     0
# dtype: int64

# %% [markdown]
# Results show that there are 0 missing values per column in all the rows.
#
# ### Entire DataFrame
#
# <code>x = df.isnull().sum().sum()</code> This will give the total count of missing  values in the entire DataFrame.

# %%
# Check for missing values in the entire DataFrame
missing_total = bigmac_df.isnull().sum().sum()
print("Total NaN values in DataFrame:", missing_total)
# Out:
# Total NaN values in DataFrame: 0

# %% [markdown]
# ### for loop
#
# Identify the entries having Null values in all columns. In the <code>missing_data</code>DataFrame, if missing = **True**, if not missing = **False**.

# %%
# Create new df
missing_data = bigmac_df.isnull()
# optional
print(missing_data.head())


# Initiate a for loop in the new DataFrame
for column in missing_data.columns.values.tolist():   #prints the name of the current column being processed
    print(column)
    print(missing_data[column].value_counts())        # calculates the count of True and False valu
    print("")                                         # easier readability
# Out:
#     date  currency_code  country  local_price  dollar_ex  dollar_price
# 0  False          False    False        False      False         False
# 1  False          False    False        False      False         False
# 2  False          False    False        False      False         False
# 3  False          False    False        False      False         False
# 4  False          False    False        False      False         False
# date
# False    1946
# Name: date, dtype: int64
#
# currency_code
# False    1946
# Name: currency_code, dtype: int64
#
# country
# False    1946
# Name: country, dtype: int64
#
# local_price
# False    1946
# Name: local_price, dtype: int64
#
# dollar_ex
# False    1946
# Name: dollar_ex, dtype: int64
#
# dollar_price
# False    1946
# Name: dollar_price, dtype: int64

# %% [markdown]
# ### There are no missing values, so there is no need to handle missing values.

# %% [markdown]
# # Streamline Analysis For Specific Countries
#
# To focus and streamline my analysis, I've decided to examine 3 specific currencies of interest, Swedish Krona, Japanese Yen and US Dollar, rather than the entire global dataset. Store the selected currencies in new DataFrame called <code>new_df</code>.

# %%
# Define the list of countries
selected_currencies = ['JPY', 'USD', 'SEK']

# Filter the DataFrame for the selected countries
new_df = bigmac_df[bigmac_df['currency_code'].isin(selected_currencies)].copy()

# Display the filtered DataFrame
print("Selected Currencies DataFrame:")
display(new_df)
# Out:
# Selected Currencies DataFrame:
#             date currency_code        country  local_price  dollar_ex  \
# 14    2000-04-01           JPY          Japan       294.00        106
# 23    2000-04-01           SEK         Sweden        24.00          8
# 27    2000-04-01           USD  United States         2.24          1
# 41    2001-04-01           JPY          Japan       294.00        124
# 51    2001-04-01           SEK         Sweden        24.00         10
# ...          ...           ...            ...          ...        ...
# 1865  2022-01-01           SEK         Sweden        54.00          9
# 1872  2022-01-01           USD  United States         5.04          1
# 1907  2022-07-01           JPY          Japan       390.00        137
# 1936  2022-07-01           SEK         Sweden        57.00         10
# 1942  2022-07-01           USD  United States         5.15          1
#
#       dollar_price
# 14            2.77
# 23            3.00
# 27            2.24
# 41            2.37
# 51            2.40
# ...            ...
# 1865          6.00
# 1872          5.04
# 1907          2.85
# 1936          5.70
# 1942          5.15
#
# [111 rows x 6 columns]

# %% [markdown]
# The result is a new DataFrame <code>new_df</code> that consists of JPY, USD and SEK taken from the 'currencies column'.

# %% [markdown]
# # Currency basis
# Aiming to focus my analysis on a currency basis before looking at the broader trends. Grouping my analysis by currency is indeed a sensible approach, especially if I want to delve into specific characteristics and trends within each country before considering broader patterns.
#
# ## Organize dataset  around individual currencies
# The 3 currencies are Swedish Krona (SEK), Japanese Yen (JPY) and US Dollars (USD).
#
# ### Group dataset by the 'currency' column
# This will allow to perform operations and analysis on each currency separately.
# I could not access United States by country, so use 'currency' columns instead.
#
# ### Japan

# %%
# Group the dataset by the 'currency' column and select only the data for Japan
japan_data = bigmac_df[bigmac_df['currency_code'] == 'JPY']

# Display the data for Japan
print("Data for Japan:")
display(japan_data)
# Out:
# Data for Japan:
#             date currency_code country  local_price  dollar_ex  dollar_price
# 14    2000-04-01           JPY   Japan        294.0        106          2.77
# 41    2001-04-01           JPY   Japan        294.0        124          2.37
# 70    2002-04-01           JPY   Japan        262.0        130          2.02
# 103   2003-04-01           JPY   Japan        262.0        120          2.18
# 137   2004-05-01           JPY   Japan        262.0        113          2.32
# 177   2005-06-01           JPY   Japan        250.0        106          2.36
# 216   2006-01-01           JPY   Japan        250.0        114          2.19
# 250   2006-05-01           JPY   Japan        250.0        112          2.23
# 291   2007-01-01           JPY   Japan        280.0        121          2.31
# 332   2007-06-01           JPY   Japan        280.0        122          2.30
# 373   2008-06-01           JPY   Japan        280.0        106          2.64
# 414   2009-07-01           JPY   Japan        320.0         92          3.48
# 455   2010-01-01           JPY   Japan        320.0         91          3.52
# 496   2010-07-01           JPY   Japan        320.0         87          3.68
# 547   2011-07-01           JPY   Japan        320.0         78          4.10
# 602   2012-01-01           JPY   Japan        320.0         76          4.21
# 656   2012-07-01           JPY   Japan        320.0         78          4.10
# 710   2013-01-01           JPY   Japan        320.0         91          3.52
# 765   2013-07-01           JPY   Japan        320.0        100          3.20
# 820   2014-01-01           JPY   Japan        310.0        104          2.98
# 876   2014-07-01           JPY   Japan        370.0        101          3.66
# 933   2015-01-01           JPY   Japan        370.0        117          3.16
# 989   2015-07-01           JPY   Japan        370.0        123          3.01
# 1045  2016-01-01           JPY   Japan        370.0        118          3.14
# 1101  2016-07-01           JPY   Japan        370.0        106          3.49
# 1157  2017-01-01           JPY   Japan        380.0        116          3.28
# 1213  2017-07-01           JPY   Japan        380.0        113          3.36
# 1269  2018-01-01           JPY   Japan        380.0        110          3.45
# 1330  2018-07-01           JPY   Japan        390.0        111          3.51
# 1402  2019-01-01           JPY   Japan        390.0        108          3.61
# 1474  2019-07-09           JPY   Japan        390.0        108          3.61
# 1546  2020-01-14           JPY   Japan        390.0        110          3.55
# 1618  2020-07-01           JPY   Japan        390.0        107          3.64
# 1690  2021-01-01           JPY   Japan        390.0        104          3.75
# 1762  2021-07-01           JPY   Japan        390.0        109          3.58
# 1835  2022-01-01           JPY   Japan        390.0        115          3.39
# 1907  2022-07-01           JPY   Japan        390.0        137          2.85

# %% [markdown]
# ### Sweden

# %%
# Group the dataset by the 'currency' column and select only the data for Sweden
sweden_data = bigmac_df[bigmac_df['currency_code'] == 'SEK']

# Display the data for Sweden
print("Data for Sweden:")
display(sweden_data)
# Out:
# Data for Sweden:
#             date currency_code country  local_price  dollar_ex  dollar_price
# 23    2000-04-01           SEK  Sweden        24.00          8          3.00
# 51    2001-04-01           SEK  Sweden        24.00         10          2.40
# 82    2002-04-01           SEK  Sweden        26.00         10          2.60
# 114   2003-04-01           SEK  Sweden        30.00          8          3.75
# 152   2004-05-01           SEK  Sweden        30.00          7          4.29
# 192   2005-06-01           SEK  Sweden        31.00          7          4.43
# 227   2006-01-01           SEK  Sweden        33.00          7          4.71
# 265   2006-05-01           SEK  Sweden        33.00          7          4.71
# 306   2007-01-01           SEK  Sweden        32.00          7          4.57
# 347   2007-06-01           SEK  Sweden        33.00          6          5.50
# 388   2008-06-01           SEK  Sweden        38.00          5          7.60
# 429   2009-07-01           SEK  Sweden        39.00          7          5.57
# 470   2010-01-01           SEK  Sweden        39.00          7          5.57
# 511   2010-07-01           SEK  Sweden        48.40          7          6.91
# 565   2011-07-01           SEK  Sweden        48.40          6          8.07
# 620   2012-01-01           SEK  Sweden        41.00          6          6.83
# 673   2012-07-01           SEK  Sweden        39.97          6          6.66
# 728   2013-01-01           SEK  Sweden        40.56          6          6.76
# 783   2013-07-01           SEK  Sweden        41.61          6          6.94
# 839   2014-01-01           SEK  Sweden        40.70          6          6.78
# 895   2014-07-01           SEK  Sweden        40.70          6          6.78
# 951   2015-01-01           SEK  Sweden        40.70          8          5.09
# 1007  2015-07-01           SEK  Sweden        43.70          8          5.46
# 1063  2016-01-01           SEK  Sweden        45.00          8          5.62
# 1119  2016-07-01           SEK  Sweden        44.94          8          5.62
# 1175  2017-01-01           SEK  Sweden        48.00          9          5.33
# 1231  2017-07-01           SEK  Sweden        48.97          8          6.12
# 1287  2018-01-01           SEK  Sweden        49.10          8          6.14
# 1360  2018-07-01           SEK  Sweden        51.00          8          6.38
# 1432  2019-01-01           SEK  Sweden        52.00          8          6.50
# 1504  2019-07-09           SEK  Sweden        51.00          9          5.67
# 1576  2020-01-14           SEK  Sweden        51.50          9          5.72
# 1648  2020-07-01           SEK  Sweden        52.60          9          5.84
# 1720  2021-01-01           SEK  Sweden        52.88          8          6.61
# 1792  2021-07-01           SEK  Sweden        54.00          8          6.75
# 1865  2022-01-01           SEK  Sweden        54.00          9          6.00
# 1936  2022-07-01           SEK  Sweden        57.00         10          5.70

# %%
### United States

# Group the dataset by the 'currency' column and select only the data for United States
usa_data = bigmac_df[bigmac_df['currency_code'] == 'USD']

# Display the data for United States
print("Data for United States:")
display(usa_data)
# Out:
# Data for United States:
#             date currency_code        country  local_price  dollar_ex  \
# 27    2000-04-01           USD  United States         2.24          1
# 55    2001-04-01           USD  United States         2.24          1
# 87    2002-04-01           USD  United States         2.35          1
# 119   2003-04-01           USD  United States         2.46          1
# 158   2004-05-01           USD  United States         2.47          1
# 199   2005-06-01           USD  United States         2.58          1
# 232   2006-01-01           USD  United States         2.67          1
# 272   2006-05-01           USD  United States         2.78          1
# 313   2007-01-01           USD  United States         2.89          1
# 354   2007-06-01           USD  United States         3.00          1
# 395   2008-06-01           USD  United States         3.21          1
# 436   2009-07-01           USD  United States         3.43          1
# 477   2010-01-01           USD  United States         3.43          1
# 518   2010-07-01           USD  United States         3.53          1
# 572   2011-07-01           USD  United States         3.64          1
# 627   2012-01-01           USD  United States         3.81          1
# 680   2012-07-01           USD  United States         3.96          1
# 735   2013-01-01           USD  United States         4.03          1
# 790   2013-07-01           USD  United States         4.18          1
# 846   2014-01-01           USD  United States         4.24          1
# 902   2014-07-01           USD  United States         4.29          1
# 958   2015-01-01           USD  United States         4.29          1
# 1014  2015-07-01           USD  United States         4.29          1
# 1070  2016-01-01           USD  United States         4.29          1
# 1126  2016-07-01           USD  United States         4.50          1
# 1182  2017-01-01           USD  United States         4.50          1
# 1238  2017-07-01           USD  United States         4.50          1
# 1294  2018-01-01           USD  United States         4.61          1
# 1367  2018-07-01           USD  United States         4.62          1
# 1439  2019-01-01           USD  United States         4.71          1
# 1511  2019-07-09           USD  United States         4.71          1
# 1583  2020-01-14           USD  United States         4.82          1
# 1655  2020-07-01           USD  United States         4.82          1
# 1727  2021-01-01           USD  United States         4.89          1
# 1799  2021-07-01           USD  United States         4.93          1
# 1872  2022-01-01           USD  United States         5.04          1
# 1942  2022-07-01           USD  United States         5.15          1
#
#       dollar_price
# 27            2.24
# 55            2.24
# 87            2.35
# 119           2.46
# 158           2.47
# 199           2.58
# 232           2.67
# 272           2.78
# 313           2.89
# 354           3.00
# 395           3.21
# 436           3.43
# 477           3.43
# 518           3.53
# 572           3.64
# 627           3.81
# 680           3.96
# 735           4.03
# 790           4.18
# 846           4.24
# 902           4.29
# 958           4.29
# 1014          4.29
# 1070          4.29
# 1126          4.50
# 1182          4.50
# 1238          4.50
# 1294          4.61
# 1367          4.62
# 1439          4.71
# 1511          4.71
# 1583          4.82
# 1655          4.82
# 1727          4.89
# 1799          4.93
# 1872          5.04
# 1942          5.15

# %% [markdown]
# # Data Binning
#
# Binning means putting similar things together in groups. In this case, create 3 bins for a new attribute.
# These bins would be named **"Low", "Medium" and "High"**.
#
# Consider using the **'local price'** and **'dollar price'** columns. These columns directly represent the prices of Big Mac in the local currency and in dollars, respectively. The **'dollar exchange'** column provides the exchange rate, which can be used to calculate the 'local price' in dollars if needed but might not be as directly relevant for binning.

# %% [markdown]
# ### Code Breakdwon: Define bin boundaries for <code>local_price</code> and <code>dollar_price</code>
#
# - <code>local_bins = [0, 3, 5, float('inf')]</code>
# This line defines the boundaries for the bins into which to categorize the <code>local_price</code>.
#
# In this case, the bins are <code>[0, 3), [3, 5), and [5, infinity)</code>.
#
# The <code>float('inf')</code> is used to represent positive infinity, meaning any value greater than 5 will fall into the **'high'** category.
#
#
# - <code>local_labels = ['low', 'medium', 'high']</code>
# This line defines the labels corresponding to each bin.
#
# The first bin <code>[0, 3)</code> is labeled as **'low'**
#
# the second bin <code>[3, 5)</code> is labeled as **'medium'**
#
# and the third bin <code>[5, infinity)</code> is labeled as **'high'**.
#
# - <code>new_df['local_price_category'] = pd.cut(new_df['local_price'], bins=local_bins, labels=local_labels)</code>
#
# This line creates a new column named <code>local_price_category</code> in the DataFrame <code>new_df</code>.
#
# It categorizes the values in the <code>local_price</code> column into the bins defined by <code>local_bins</code> and assigns the corresponding labels defined by <code>local_labels</code> to each value based on its bin.
#
# - <code>pd.cut()</code> returns a new categorical variable representing the binning of the original data.

# %%
# Define bin boundaries for local price
local_bins = [0, 3, 5, float('inf')]
local_labels = ['low', 'medium', 'high']
new_df['local_price_category'] = pd.cut(new_df['local_price'], bins=local_bins, labels=local_labels)

# Define bin boundaries for dollar price
dollar_bins = [0, 2, 4, float('inf')]
dollar_labels = ['low', 'medium', 'high']
new_df['dollar_price_category'] = pd.cut(new_df['dollar_price'], bins=dollar_bins, labels=dollar_labels)

# Display the updated DataFrame with price categories
display(new_df)
# Out:
#             date currency_code        country  local_price  dollar_ex  \
# 14    2000-04-01           JPY          Japan       294.00        106
# 23    2000-04-01           SEK         Sweden        24.00          8
# 27    2000-04-01           USD  United States         2.24          1
# 41    2001-04-01           JPY          Japan       294.00        124
# 51    2001-04-01           SEK         Sweden        24.00         10
# ...          ...           ...            ...          ...        ...
# 1865  2022-01-01           SEK         Sweden        54.00          9
# 1872  2022-01-01           USD  United States         5.04          1
# 1907  2022-07-01           JPY          Japan       390.00        137
# 1936  2022-07-01           SEK         Sweden        57.00         10
# 1942  2022-07-01           USD  United States         5.15          1
#
#       dollar_price local_price_category dollar_price_category
# 14            2.77                 high                medium
# 23            3.00                 high                medium
# 27            2.24                  low                medium
# 41            2.37                 high                medium
# 51            2.40                 high                medium
# ...            ...                  ...                   ...
# 1865          6.00                 high                  high
# 1872          5.04                 high                  high
# 1907          2.85                 high                medium
# 1936          5.70                 high                  high
# 1942          5.15                 high                  high
#
# [111 rows x 8 columns]

# %% [markdown]
# ### Code Breakdown: Filter DataFrame by <code>currency_code</code> after <code>local_price</code> and <code>dollar_price</code>
#
# - <code>dollar_bins = [0, 2, 4, float('inf')]</code>
#
# Similar to the previous section, this line defines the bin boundaries for the <code>dollar_price</code> data. The bins are <code>[0, 2), [2, 4), and [4, infinity)</code>.
#
# - <code>dollar_labels = ['low', 'medium', 'high']</code>
#
# Defines the corresponding labels for the dollar price bins.
#
# - <code>new_df['dollar_price_category'] = pd.cut(new_df['dollar_price'], bins=dollar_bins, labels=dollar_labels)</code>
#
# This line creates a new column named <code>dollar_price_category</code> in the DataFrame <code>new_df</code>.
#
# It categorizes the values in the <code>dollar_price</code> column into the bins defined by <code>dollar_bins</code> and assigns the corresponding labels defined by <code>dollar_labels</code> to each value based on its bin.

# %%
# Filter DataFrame by currency code
usd_df = new_df[new_df['currency_code'] == 'USD']
sek_df = new_df[new_df['currency_code'] == 'SEK']
jpy_df = new_df[new_df['currency_code'] == 'JPY']

# Display DataFrames for each currency code
print("Data for USD:")
display(usd_df)
# Out:
# Data for USD:
#             date currency_code        country  local_price  dollar_ex  \
# 27    2000-04-01           USD  United States         2.24          1
# 55    2001-04-01           USD  United States         2.24          1
# 87    2002-04-01           USD  United States         2.35          1
# 119   2003-04-01           USD  United States         2.46          1
# 158   2004-05-01           USD  United States         2.47          1
# 199   2005-06-01           USD  United States         2.58          1
# 232   2006-01-01           USD  United States         2.67          1
# 272   2006-05-01           USD  United States         2.78          1
# 313   2007-01-01           USD  United States         2.89          1
# 354   2007-06-01           USD  United States         3.00          1
# 395   2008-06-01           USD  United States         3.21          1
# 436   2009-07-01           USD  United States         3.43          1
# 477   2010-01-01           USD  United States         3.43          1
# 518   2010-07-01           USD  United States         3.53          1
# 572   2011-07-01           USD  United States         3.64          1
# 627   2012-01-01           USD  United States         3.81          1
# 680   2012-07-01           USD  United States         3.96          1
# 735   2013-01-01           USD  United States         4.03          1
# 790   2013-07-01           USD  United States         4.18          1
# 846   2014-01-01           USD  United States         4.24          1
# 902   2014-07-01           USD  United States         4.29          1
# 958   2015-01-01           USD  United States         4.29          1
# 1014  2015-07-01           USD  United States         4.29          1
# 1070  2016-01-01           USD  United States         4.29          1
# 1126  2016-07-01           USD  United States         4.50          1
# 1182  2017-01-01           USD  United States         4.50          1
# 1238  2017-07-01           USD  United States         4.50          1
# 1294  2018-01-01           USD  United States         4.61          1
# 1367  2018-07-01           USD  United States         4.62          1
# 1439  2019-01-01           USD  United States         4.71          1
# 1511  2019-07-09           USD  United States         4.71          1
# 1583  2020-01-14           USD  United States         4.82          1
# 1655  2020-07-01           USD  United States         4.82          1
# 1727  2021-01-01           USD  United States         4.89          1
# 1799  2021-07-01           USD  United States         4.93          1
# 1872  2022-01-01           USD  United States         5.04          1
# 1942  2022-07-01           USD  United States         5.15          1
#
#       dollar_price local_price_category dollar_price_category
# 27            2.24                  low                medium
# 55            2.24                  low                medium
# 87            2.35                  low                medium
# 119           2.46                  low                medium
# 158           2.47                  low                medium
# 199           2.58                  low                medium
# 232           2.67                  low                medium
# 272           2.78                  low                medium
# 313           2.89                  low                medium
# 354           3.00                  low                medium
# 395           3.21               medium                medium
# 436           3.43               medium                medium
# 477           3.43               medium                medium
# 518           3.53               medium                medium
# 572           3.64               medium                medium
# 627           3.81               medium                medium
# 680           3.96               medium                medium
# 735           4.03               medium                  high
# 790           4.18               medium                  high
# 846           4.24               medium                  high
# 902           4.29               medium                  high
# 958           4.29               medium                  high
# 1014          4.29               medium                  high
# 1070          4.29               medium                  high
# 1126          4.50               medium                  high
# 1182          4.50               medium                  high
# 1238          4.50               medium                  high
# 1294          4.61               medium                  high
# 1367          4.62               medium                  high
# 1439          4.71               medium                  high
# 1511          4.71               medium                  high
# 1583          4.82               medium                  high
# 1655          4.82               medium                  high
# 1727          4.89               medium                  high
# 1799          4.93               medium                  high
# 1872          5.04                 high                  high
# 1942          5.15                 high                  high

# %% [markdown]
# ### Reset the indexes from 1
#
# The newly reset DataFrames for each currency will be stored in the following: <code>sek_df</code>, <code>jpy_df</code> and <code>usd_df</code>.
#
# Instead of using the default index, use the <code>reset_index()</code> method to fix the index from 1.
#
# <code>inplace = True</code>
# Modify the DataFrame object in place and apply changes directly to DataFrame object.
#
# <code>drop = True</code>
# To drop the old index column and reset

# %%
# reset index from 1
usd_df.reset_index(drop = True, inplace = True)
print("Data for USA:")
display(usd_df)
# Out:
# Data for USA:
#           date currency_code        country  local_price  dollar_ex  \
# 0   2000-04-01           USD  United States         2.24          1
# 1   2001-04-01           USD  United States         2.24          1
# 2   2002-04-01           USD  United States         2.35          1
# 3   2003-04-01           USD  United States         2.46          1
# 4   2004-05-01           USD  United States         2.47          1
# 5   2005-06-01           USD  United States         2.58          1
# 6   2006-01-01           USD  United States         2.67          1
# 7   2006-05-01           USD  United States         2.78          1
# 8   2007-01-01           USD  United States         2.89          1
# 9   2007-06-01           USD  United States         3.00          1
# 10  2008-06-01           USD  United States         3.21          1
# 11  2009-07-01           USD  United States         3.43          1
# 12  2010-01-01           USD  United States         3.43          1
# 13  2010-07-01           USD  United States         3.53          1
# 14  2011-07-01           USD  United States         3.64          1
# 15  2012-01-01           USD  United States         3.81          1
# 16  2012-07-01           USD  United States         3.96          1
# 17  2013-01-01           USD  United States         4.03          1
# 18  2013-07-01           USD  United States         4.18          1
# 19  2014-01-01           USD  United States         4.24          1
# 20  2014-07-01           USD  United States         4.29          1
# 21  2015-01-01           USD  United States         4.29          1
# 22  2015-07-01           USD  United States         4.29          1
# 23  2016-01-01           USD  United States         4.29          1
# 24  2016-07-01           USD  United States         4.50          1
# 25  2017-01-01           USD  United States         4.50          1
# 26  2017-07-01           USD  United States         4.50          1
# 27  2018-01-01           USD  United States         4.61          1
# 28  2018-07-01           USD  United States         4.62          1
# 29  2019-01-01           USD  United States         4.71          1
# 30  2019-07-09           USD  United States         4.71          1
# 31  2020-01-14           USD  United States         4.82          1
# 32  2020-07-01           USD  United States         4.82          1
# 33  2021-01-01           USD  United States         4.89          1
# 34  2021-07-01           USD  United States         4.93          1
# 35  2022-01-01           USD  United States         5.04          1
# 36  2022-07-01           USD  United States         5.15          1
#
#     dollar_price local_price_category dollar_price_category
# 0           2.24                  low                medium
# 1           2.24                  low                medium
# 2           2.35                  low                medium
# 3           2.46                  low                medium
# 4           2.47                  low                medium
# 5           2.58                  low                medium
# 6           2.67                  low                medium
# 7           2.78                  low                medium
# 8           2.89                  low                medium
# 9           3.00                  low                medium
# 10          3.21               medium                medium
# 11          3.43               medium                medium
# 12          3.43               medium                medium
# 13          3.53               medium                medium
# 14          3.64               medium                medium
# 15          3.81               medium                medium
# 16          3.96               medium                medium
# 17          4.03               medium                  high
# 18          4.18               medium                  high
# 19          4.24               medium                  high
# 20          4.29               medium                  high
# 21          4.29               medium                  high
# 22          4.29               medium                  high
# 23          4.29               medium                  high
# 24          4.50               medium                  high
# 25          4.50               medium                  high
# 26          4.50               medium                  high
# 27          4.61               medium                  high
# 28          4.62               medium                  high
# 29          4.71               medium                  high
# 30          4.71               medium                  high
# 31          4.82               medium                  high
# 32          4.82               medium                  high
# 33          4.89               medium                  high
# 34          4.93               medium                  high
# 35          5.04                 high                  high
# 36          5.15                 high                  high

# %%
# Display DataFrames for each currency code
print("\nData for SEK:")
display(sek_df)
# Out:
# Data for SEK:
#             date currency_code country  local_price  dollar_ex  dollar_price  \
# 23    2000-04-01           SEK  Sweden        24.00          8          3.00
# 51    2001-04-01           SEK  Sweden        24.00         10          2.40
# 82    2002-04-01           SEK  Sweden        26.00         10          2.60
# 114   2003-04-01           SEK  Sweden        30.00          8          3.75
# 152   2004-05-01           SEK  Sweden        30.00          7          4.29
# 192   2005-06-01           SEK  Sweden        31.00          7          4.43
# 227   2006-01-01           SEK  Sweden        33.00          7          4.71
# 265   2006-05-01           SEK  Sweden        33.00          7          4.71
# 306   2007-01-01           SEK  Sweden        32.00          7          4.57
# 347   2007-06-01           SEK  Sweden        33.00          6          5.50
# 388   2008-06-01           SEK  Sweden        38.00          5          7.60
# 429   2009-07-01           SEK  Sweden        39.00          7          5.57
# 470   2010-01-01           SEK  Sweden        39.00          7          5.57
# 511   2010-07-01           SEK  Sweden        48.40          7          6.91
# 565   2011-07-01           SEK  Sweden        48.40          6          8.07
# 620   2012-01-01           SEK  Sweden        41.00          6          6.83
# 673   2012-07-01           SEK  Sweden        39.97          6          6.66
# 728   2013-01-01           SEK  Sweden        40.56          6          6.76
# 783   2013-07-01           SEK  Sweden        41.61          6          6.94
# 839   2014-01-01           SEK  Sweden        40.70          6          6.78
# 895   2014-07-01           SEK  Sweden        40.70          6          6.78
# 951   2015-01-01           SEK  Sweden        40.70          8          5.09
# 1007  2015-07-01           SEK  Sweden        43.70          8          5.46
# 1063  2016-01-01           SEK  Sweden        45.00          8          5.62
# 1119  2016-07-01           SEK  Sweden        44.94          8          5.62
# 1175  2017-01-01           SEK  Sweden        48.00          9          5.33
# 1231  2017-07-01           SEK  Sweden        48.97          8          6.12
# 1287  2018-01-01           SEK  Sweden        49.10          8          6.14
# 1360  2018-07-01           SEK  Sweden        51.00          8          6.38
# 1432  2019-01-01           SEK  Sweden        52.00          8          6.50
# 1504  2019-07-09           SEK  Sweden        51.00          9          5.67
# 1576  2020-01-14           SEK  Sweden        51.50          9          5.72
# 1648  2020-07-01           SEK  Sweden        52.60          9          5.84
# 1720  2021-01-01           SEK  Sweden        52.88          8          6.61
# 1792  2021-07-01           SEK  Sweden        54.00          8          6.75
# 1865  2022-01-01           SEK  Sweden        54.00          9          6.00
# 1936  2022-07-01           SEK  Sweden        57.00         10          5.70
#
#      local_price_category dollar_price_category
# 23                   high                medium
# 51                   high                medium
# 82                   high                medium
# 114                  high                medium
# 152                  high                  high
# 192                  high                  high
# 227                  high                  high
# 265                  high                  high
# 306                  high                  high
# 347                  high                  high
# 388                  high                  high
# 429                  high                  high
# 470                  high                  high
# 511                  high                  high
# 565                  high                  high
# 620                  high                  high
# 673                  high                  high
# 728                  high                  high
# 783                  high                  high
# 839                  high                  high
# 895                  high                  high
# 951                  high                  high
# 1007                 high                  high
# 1063                 high                  high
# 1119                 high                  high
# 1175                 high                  high
# 1231                 high                  high
# 1287                 high                  high
# 1360                 high                  high
# 1432                 high                  high
# 1504                 high                  high
# 1576                 high                  high
# 1648                 high                  high
# 1720                 high                  high
# 1792                 high                  high
# 1865                 high                  high
# 1936                 high                  high

# %%
# reset index from 1
sek_df.reset_index(drop = True, inplace = True)
print("Data for Sweden:")
display(sek_df)
# Out:
# Data for Sweden:
#           date currency_code country  local_price  dollar_ex  dollar_price  \
# 0   2000-04-01           SEK  Sweden        24.00          8          3.00
# 1   2001-04-01           SEK  Sweden        24.00         10          2.40
# 2   2002-04-01           SEK  Sweden        26.00         10          2.60
# 3   2003-04-01           SEK  Sweden        30.00          8          3.75
# 4   2004-05-01           SEK  Sweden        30.00          7          4.29
# 5   2005-06-01           SEK  Sweden        31.00          7          4.43
# 6   2006-01-01           SEK  Sweden        33.00          7          4.71
# 7   2006-05-01           SEK  Sweden        33.00          7          4.71
# 8   2007-01-01           SEK  Sweden        32.00          7          4.57
# 9   2007-06-01           SEK  Sweden        33.00          6          5.50
# 10  2008-06-01           SEK  Sweden        38.00          5          7.60
# 11  2009-07-01           SEK  Sweden        39.00          7          5.57
# 12  2010-01-01           SEK  Sweden        39.00          7          5.57
# 13  2010-07-01           SEK  Sweden        48.40          7          6.91
# 14  2011-07-01           SEK  Sweden        48.40          6          8.07
# 15  2012-01-01           SEK  Sweden        41.00          6          6.83
# 16  2012-07-01           SEK  Sweden        39.97          6          6.66
# 17  2013-01-01           SEK  Sweden        40.56          6          6.76
# 18  2013-07-01           SEK  Sweden        41.61          6          6.94
# 19  2014-01-01           SEK  Sweden        40.70          6          6.78
# 20  2014-07-01           SEK  Sweden        40.70          6          6.78
# 21  2015-01-01           SEK  Sweden        40.70          8          5.09
# 22  2015-07-01           SEK  Sweden        43.70          8          5.46
# 23  2016-01-01           SEK  Sweden        45.00          8          5.62
# 24  2016-07-01           SEK  Sweden        44.94          8          5.62
# 25  2017-01-01           SEK  Sweden        48.00          9          5.33
# 26  2017-07-01           SEK  Sweden        48.97          8          6.12
# 27  2018-01-01           SEK  Sweden        49.10          8          6.14
# 28  2018-07-01           SEK  Sweden        51.00          8          6.38
# 29  2019-01-01           SEK  Sweden        52.00          8          6.50
# 30  2019-07-09           SEK  Sweden        51.00          9          5.67
# 31  2020-01-14           SEK  Sweden        51.50          9          5.72
# 32  2020-07-01           SEK  Sweden        52.60          9          5.84
# 33  2021-01-01           SEK  Sweden        52.88          8          6.61
# 34  2021-07-01           SEK  Sweden        54.00          8          6.75
# 35  2022-01-01           SEK  Sweden        54.00          9          6.00
# 36  2022-07-01           SEK  Sweden        57.00         10          5.70
#
#    local_price_category dollar_price_category
# 0                  high                medium
# 1                  high                medium
# 2                  high                medium
# 3                  high                medium
# 4                  high                  high
# 5                  high                  high
# 6                  high                  high
# 7                  high                  high
# 8                  high                  high
# 9                  high                  high
# 10                 high                  high
# 11                 high                  high
# 12                 high                  high
# 13                 high                  high
# 14                 high                  high
# 15                 high                  high
# 16                 high                  high
# 17                 high                  high
# 18                 high                  high
# 19                 high                  high
# 20                 high                  high
# 21                 high                  high
# 22                 high                  high
# 23                 high                  high
# 24                 high                  high
# 25                 high                  high
# 26                 high                  high
# 27                 high                  high
# 28                 high                  high
# 29                 high                  high
# 30                 high                  high
# 31                 high                  high
# 32                 high                  high
# 33                 high                  high
# 34                 high                  high
# 35                 high                  high
# 36                 high                  high

# %%
# Display DataFrames for each currency code
print("\nData for JPY:")
display(jpy_df)
# Out:
# Data for JPY:
#             date currency_code country  local_price  dollar_ex  dollar_price  \
# 14    2000-04-01           JPY   Japan        294.0        106          2.77
# 41    2001-04-01           JPY   Japan        294.0        124          2.37
# 70    2002-04-01           JPY   Japan        262.0        130          2.02
# 103   2003-04-01           JPY   Japan        262.0        120          2.18
# 137   2004-05-01           JPY   Japan        262.0        113          2.32
# 177   2005-06-01           JPY   Japan        250.0        106          2.36
# 216   2006-01-01           JPY   Japan        250.0        114          2.19
# 250   2006-05-01           JPY   Japan        250.0        112          2.23
# 291   2007-01-01           JPY   Japan        280.0        121          2.31
# 332   2007-06-01           JPY   Japan        280.0        122          2.30
# 373   2008-06-01           JPY   Japan        280.0        106          2.64
# 414   2009-07-01           JPY   Japan        320.0         92          3.48
# 455   2010-01-01           JPY   Japan        320.0         91          3.52
# 496   2010-07-01           JPY   Japan        320.0         87          3.68
# 547   2011-07-01           JPY   Japan        320.0         78          4.10
# 602   2012-01-01           JPY   Japan        320.0         76          4.21
# 656   2012-07-01           JPY   Japan        320.0         78          4.10
# 710   2013-01-01           JPY   Japan        320.0         91          3.52
# 765   2013-07-01           JPY   Japan        320.0        100          3.20
# 820   2014-01-01           JPY   Japan        310.0        104          2.98
# 876   2014-07-01           JPY   Japan        370.0        101          3.66
# 933   2015-01-01           JPY   Japan        370.0        117          3.16
# 989   2015-07-01           JPY   Japan        370.0        123          3.01
# 1045  2016-01-01           JPY   Japan        370.0        118          3.14
# 1101  2016-07-01           JPY   Japan        370.0        106          3.49
# 1157  2017-01-01           JPY   Japan        380.0        116          3.28
# 1213  2017-07-01           JPY   Japan        380.0        113          3.36
# 1269  2018-01-01           JPY   Japan        380.0        110          3.45
# 1330  2018-07-01           JPY   Japan        390.0        111          3.51
# 1402  2019-01-01           JPY   Japan        390.0        108          3.61
# 1474  2019-07-09           JPY   Japan        390.0        108          3.61
# 1546  2020-01-14           JPY   Japan        390.0        110          3.55
# 1618  2020-07-01           JPY   Japan        390.0        107          3.64
# 1690  2021-01-01           JPY   Japan        390.0        104          3.75
# 1762  2021-07-01           JPY   Japan        390.0        109          3.58
# 1835  2022-01-01           JPY   Japan        390.0        115          3.39
# 1907  2022-07-01           JPY   Japan        390.0        137          2.85
#
#      local_price_category dollar_price_category
# 14                   high                medium
# 41                   high                medium
# 70                   high                medium
# 103                  high                medium
# 137                  high                medium
# 177                  high                medium
# 216                  high                medium
# 250                  high                medium
# 291                  high                medium
# 332                  high                medium
# 373                  high                medium
# 414                  high                medium
# 455                  high                medium
# 496                  high                medium
# 547                  high                  high
# 602                  high                  high
# 656                  high                  high
# 710                  high                medium
# 765                  high                medium
# 820                  high                medium
# 876                  high                medium
# 933                  high                medium
# 989                  high                medium
# 1045                 high                medium
# 1101                 high                medium
# 1157                 high                medium
# 1213                 high                medium
# 1269                 high                medium
# 1330                 high                medium
# 1402                 high                medium
# 1474                 high                medium
# 1546                 high                medium
# 1618                 high                medium
# 1690                 high                medium
# 1762                 high                medium
# 1835                 high                medium
# 1907                 high                medium

# %%
# reset index from 1
jpy_df.reset_index(drop = True, inplace = True)
print("Data for Japan:")
display(jpy_df)
# Out:
# Data for Japan:
#           date currency_code country  local_price  dollar_ex  dollar_price  \
# 0   2000-04-01           JPY   Japan        294.0        106          2.77
# 1   2001-04-01           JPY   Japan        294.0        124          2.37
# 2   2002-04-01           JPY   Japan        262.0        130          2.02
# 3   2003-04-01           JPY   Japan        262.0        120          2.18
# 4   2004-05-01           JPY   Japan        262.0        113          2.32
# 5   2005-06-01           JPY   Japan        250.0        106          2.36
# 6   2006-01-01           JPY   Japan        250.0        114          2.19
# 7   2006-05-01           JPY   Japan        250.0        112          2.23
# 8   2007-01-01           JPY   Japan        280.0        121          2.31
# 9   2007-06-01           JPY   Japan        280.0        122          2.30
# 10  2008-06-01           JPY   Japan        280.0        106          2.64
# 11  2009-07-01           JPY   Japan        320.0         92          3.48
# 12  2010-01-01           JPY   Japan        320.0         91          3.52
# 13  2010-07-01           JPY   Japan        320.0         87          3.68
# 14  2011-07-01           JPY   Japan        320.0         78          4.10
# 15  2012-01-01           JPY   Japan        320.0         76          4.21
# 16  2012-07-01           JPY   Japan        320.0         78          4.10
# 17  2013-01-01           JPY   Japan        320.0         91          3.52
# 18  2013-07-01           JPY   Japan        320.0        100          3.20
# 19  2014-01-01           JPY   Japan        310.0        104          2.98
# 20  2014-07-01           JPY   Japan        370.0        101          3.66
# 21  2015-01-01           JPY   Japan        370.0        117          3.16
# 22  2015-07-01           JPY   Japan        370.0        123          3.01
# 23  2016-01-01           JPY   Japan        370.0        118          3.14
# 24  2016-07-01           JPY   Japan        370.0        106          3.49
# 25  2017-01-01           JPY   Japan        380.0        116          3.28
# 26  2017-07-01           JPY   Japan        380.0        113          3.36
# 27  2018-01-01           JPY   Japan        380.0        110          3.45
# 28  2018-07-01           JPY   Japan        390.0        111          3.51
# 29  2019-01-01           JPY   Japan        390.0        108          3.61
# 30  2019-07-09           JPY   Japan        390.0        108          3.61
# 31  2020-01-14           JPY   Japan        390.0        110          3.55
# 32  2020-07-01           JPY   Japan        390.0        107          3.64
# 33  2021-01-01           JPY   Japan        390.0        104          3.75
# 34  2021-07-01           JPY   Japan        390.0        109          3.58
# 35  2022-01-01           JPY   Japan        390.0        115          3.39
# 36  2022-07-01           JPY   Japan        390.0        137          2.85
#
#    local_price_category dollar_price_category
# 0                  high                medium
# 1                  high                medium
# 2                  high                medium
# 3                  high                medium
# 4                  high                medium
# 5                  high                medium
# 6                  high                medium
# 7                  high                medium
# 8                  high                medium
# 9                  high                medium
# 10                 high                medium
# 11                 high                medium
# 12                 high                medium
# 13                 high                medium
# 14                 high                  high
# 15                 high                  high
# 16                 high                  high
# 17                 high                medium
# 18                 high                medium
# 19                 high                medium
# 20                 high                medium
# 21                 high                medium
# 22                 high                medium
# 23                 high                medium
# 24                 high                medium
# 25                 high                medium
# 26                 high                medium
# 27                 high                medium
# 28                 high                medium
# 29                 high                medium
# 30                 high                medium
# 31                 high                medium
# 32                 high                medium
# 33                 high                medium
# 34                 high                medium
# 35                 high                medium
# 36                 high                medium

# %% [markdown]
# ### value_counts()
# Count the occurrences of each category in the binned columns per country.

# %%
# Print the count of each price category for local price
print("JPY: local price category\n", jpy_df['local_price_category'].value_counts())
print('\n')

# Print the count of each price category for dollar price
print("JPY: dollar price category\n", jpy_df['dollar_price_category'].value_counts())
# Out:
# JPY: local price category
#  high      37
# low        0
# medium     0
# Name: local_price_category, dtype: int64
#
#
# JPY: dollar price category
#  medium    34
# high       3
# low        0
# Name: dollar_price_category, dtype: int64

# %%
# Print the count of each price category for local price
print("SEK: local price category\n", sek_df['local_price_category'].value_counts())
print('\n')

# Print the count of each price category for dollar price
print("SEK: dollar price category\n", sek_df['dollar_price_category'].value_counts())
# Out:
# SEK: local price category
#  high      37
# low        0
# medium     0
# Name: local_price_category, dtype: int64
#
#
# SEK: dollar price category
#  high      33
# medium     4
# low        0
# Name: dollar_price_category, dtype: int64

# %%
# Print the count of each price category for local price
print("USD: local price category\n", usd_df['local_price_category'].value_counts())
print('\n')

# Print the count of each price category for dollar price
print("USD: dollar price category\n", usd_df['dollar_price_category'].value_counts())
# Out:
# USD: local price category
#  medium    25
# low       10
# high       2
# Name: local_price_category, dtype: int64
#
#
# USD: dollar price category
#  high      20
# medium    17
# low        0
# Name: dollar_price_category, dtype: int64

# %% [markdown]
# # Summary Statistics
#
# Use the describe() method by giving a summary of the data's main points like its average, spread, and overall shape, which saves time from having to look at each separate piece of data. This can be really useful when trying to understand each currency's DataFrame.

# %%
sek_summary = sek_df.describe()
print("Sweden Summary Statistic\n",sek_summary)
# Out:
# Sweden Summary Statistic
#         local_price  dollar_ex  dollar_price
# count    37.000000  37.000000     37.000000
# mean     41.884595   7.567568      5.648108
# std       9.182339   1.281070      1.295093
# min      24.000000   5.000000      2.400000
# 25%      33.000000   7.000000      5.090000
# 50%      41.000000   8.000000      5.700000
# 75%      49.100000   8.000000      6.660000
# max      57.000000  10.000000      8.070000

# %%
jpy_summary = jpy_df.describe()
print("Japan Summary Statistic\n",jpy_summary)
# Out:
# Japan Summary Statistic
#         local_price   dollar_ex  dollar_price
# count    37.000000   37.000000     37.000000
# mean    333.351351  107.675676      3.149189
# std      50.510844   13.930490      0.613625
# min     250.000000   76.000000      2.020000
# 25%     294.000000  104.000000      2.640000
# 50%     320.000000  109.000000      3.360000
# 75%     380.000000  116.000000      3.580000
# max     390.000000  137.000000      4.210000

# %%
usd_summary = usd_df.describe()
print("United States Summary Statistic\n",usd_summary)
# Out:
# United States Summary Statistic
#         local_price  dollar_ex  dollar_price
# count    37.000000       37.0     37.000000
# mean      3.840541        1.0      3.840541
# std       0.915987        0.0      0.915987
# min       2.240000        1.0      2.240000
# 25%       3.000000        1.0      3.000000
# 50%       4.180000        1.0      4.180000
# 75%       4.610000        1.0      4.610000
# max       5.150000        1.0      5.150000

# %% [markdown]
# # Reporting
#
# ## Local Price and Dollar Price Interpretation
#
# **Japan**
# In Japan, Big Mac prices are generally high. This is evident from the fact that most prices, when seen in Japanese yen (JPY), are categorized as "high." Even when viewed in dollars, there are still many instances where prices are considered "medium." Overall, whether you look at prices in yen or dollars, Big Macs in Japan tend to be relatively expensive compared to other places. This could be due to factors like Japan's economic conditions, purchasing power, exchange rates, and local market trends.
#
# **Sweden**
# In Sweden, all local prices and nearly all dollar prices are categorized as "high." This suggests that Big Mac prices in Sweden, when viewed in Swedish krona (SEK), are consistently high throughout the dataset.
#
# In conclusion, buying a Big Mac in Sweden is generally seen as expensive. This corresponds with Sweden's reputation as a high-cost country, where the prices of goods, including fast food items like Big Macs, reflect this characteristic of the economy.
#
# **United States**
#
# In the United States, while most local prices are categorized as "medium," indicating a moderate pricing level, there are also notable occurrences in the "low" category. However, the occurrences categorized as "high" are relatively few compared to the other categories.
#
# Regarding dollar prices, there is a relatively even distribution between "high" and "medium" categories. This suggests that when viewing Big Mac prices in the United States in terms of dollars, there is variability, with a significant number falling into the "high" category.
#
# In summary, purchasing a Big Mac in the United States comes with varying price levels. While a considerable proportion falls into the "medium" category for both local and dollar prices, there are instances of higher-priced Big Macs, particularly when considering prices in dollars. This diversity reflects the economic conditions across different regions of the country.
#
# ## Summary Statistics Results
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Export DataFrame from Jupyter Notebook
#
# ## Convert pd.df from .ipynb file to csv file
#
# To export data from a Jupyter Notebook (.ipynb file) to a CSV or Excel format, you need to first extract the data from your notebook.
#
# ## Concatenate all 3 DataFrames into 1
#
# - **Convert to DataFrame (if necessary)**
# Combine these dataframes: <code>jpy_df, sek_df, usd_df</code> into one using the <code>pd.concat()</code> function in pandas.

# %%
# Concatenate the dataframes along the columns axis (axis=1)
combined_df = pd.concat([jpy_df, sek_df, usd_df], axis=1)

display(combined_df)
# Out:
#          date  currency_code  country local_price dollar_ex dollar_price  \
# 0  2000-04-01            JPY    Japan       294.0       106         2.77
# 1  2001-04-01            JPY    Japan       294.0       124         2.37
# 2  2002-04-01            JPY    Japan       262.0       130         2.02
# 3  2003-04-01            JPY    Japan       262.0       120         2.18
# 4  2004-05-01            JPY    Japan       262.0       113         2.32
# 5  2005-06-01            JPY    Japan       250.0       106         2.36
# 6  2006-01-01            JPY    Japan       250.0       114         2.19
# 7  2006-05-01            JPY    Japan       250.0       112         2.23
# 8  2007-01-01            JPY    Japan       280.0       121         2.31
# 9  2007-06-01            JPY    Japan       280.0       122         2.30
# 10 2008-06-01            JPY    Japan       280.0       106         2.64
# 11 2009-07-01            JPY    Japan       320.0        92         3.48
# 12 2010-01-01            JPY    Japan       320.0        91         3.52
# 13 2010-07-01            JPY    Japan       320.0        87         3.68
# 14 2011-07-01            JPY    Japan       320.0        78         4.10
# 15 2012-01-01            JPY    Japan       320.0        76         4.21
# 16 2012-07-01            JPY    Japan       320.0        78         4.10
# 17 2013-01-01            JPY    Japan       320.0        91         3.52
# 18 2013-07-01            JPY    Japan       320.0       100         3.20
# 19 2014-01-01            JPY    Japan       310.0       104         2.98
# 20 2014-07-01            JPY    Japan       370.0       101         3.66
# 21 2015-01-01            JPY    Japan       370.0       117         3.16
# 22 2015-07-01            JPY    Japan       370.0       123         3.01
# 23 2016-01-01            JPY    Japan       370.0       118         3.14
# 24 2016-07-01            JPY    Japan       370.0       106         3.49
# 25 2017-01-01            JPY    Japan       380.0       116         3.28
# 26 2017-07-01            JPY    Japan       380.0       113         3.36
# 27 2018-01-01            JPY    Japan       380.0       110         3.45
# 28 2018-07-01            JPY    Japan       390.0       111         3.51
# 29 2019-01-01            JPY    Japan       390.0       108         3.61
# 30 2019-07-09            JPY    Japan       390.0       108         3.61
# 31 2020-01-14            JPY    Japan       390.0       110         3.55
# 32 2020-07-01            JPY    Japan       390.0       107         3.64
# 33 2021-01-01            JPY    Japan       390.0       104         3.75
# 34 2021-07-01            JPY    Japan       390.0       109         3.58
# 35 2022-01-01            JPY    Japan       390.0       115         3.39
# 36 2022-07-01            JPY    Japan       390.0       137         2.85
#
#    local_price_category dollar_price_category  year        date  ...  \
# 0                  high                medium  2000  2000-04-01  ...
# 1                  high                medium  2001  2001-04-01  ...
# 2                  high                medium  2002  2002-04-01  ...
# 3                  high                medium  2003  2003-04-01  ...
# 4                  high                medium  2004  2004-05-01  ...
# 5                  high                medium  2005  2005-06-01  ...
# 6                  high                medium  2006  2006-01-01  ...
# 7                  high                medium  2006  2006-05-01  ...
# 8                  high                medium  2007  2007-01-01  ...
# 9                  high                medium  2007  2007-06-01  ...
# 10                 high                medium  2008  2008-06-01  ...
# 11                 high                medium  2009  2009-07-01  ...
# 12                 high                medium  2010  2010-01-01  ...
# 13                 high                medium  2010  2010-07-01  ...
# 14                 high                  high  2011  2011-07-01  ...
# 15                 high                  high  2012  2012-01-01  ...
# 16                 high                  high  2012  2012-07-01  ...
# 17                 high                medium  2013  2013-01-01  ...
# 18                 high                medium  2013  2013-07-01  ...
# 19                 high                medium  2014  2014-01-01  ...
# 20                 high                medium  2014  2014-07-01  ...
# 21                 high                medium  2015  2015-01-01  ...
# 22                 high                medium  2015  2015-07-01  ...
# 23                 high                medium  2016  2016-01-01  ...
# 24                 high                medium  2016  2016-07-01  ...
# 25                 high                medium  2017  2017-01-01  ...
# 26                 high                medium  2017  2017-07-01  ...
# 27                 high                medium  2018  2018-01-01  ...
# 28                 high                medium  2018  2018-07-01  ...
# 29                 high                medium  2019  2019-01-01  ...
# 30                 high                medium  2019  2019-07-09  ...
# 31                 high                medium  2020  2020-01-14  ...
# 32                 high                medium  2020  2020-07-01  ...
# 33                 high                medium  2021  2021-01-01  ...
# 34                 high                medium  2021  2021-07-01  ...
# 35                 high                medium  2022  2022-01-01  ...
# 36                 high                medium  2022  2022-07-01  ...
#
#    local_price_category dollar_price_category        date  currency_code  \
# 0                  high                medium  2000-04-01            USD
# 1                  high                medium  2001-04-01            USD
# 2                  high                medium  2002-04-01            USD
# 3                  high                medium  2003-04-01            USD
# 4                  high                  high  2004-05-01            USD
# 5                  high                  high  2005-06-01            USD
# 6                  high                  high  2006-01-01            USD
# 7                  high                  high  2006-05-01            USD
# 8                  high                  high  2007-01-01            USD
# 9                  high                  high  2007-06-01            USD
# 10                 high                  high  2008-06-01            USD
# 11                 high                  high  2009-07-01            USD
# 12                 high                  high  2010-01-01            USD
# 13                 high                  high  2010-07-01            USD
# 14                 high                  high  2011-07-01            USD
# 15                 high                  high  2012-01-01            USD
# 16                 high                  high  2012-07-01            USD
# 17                 high                  high  2013-01-01            USD
# 18                 high                  high  2013-07-01            USD
# 19                 high                  high  2014-01-01            USD
# 20                 high                  high  2014-07-01            USD
# 21                 high                  high  2015-01-01            USD
# 22                 high                  high  2015-07-01            USD
# 23                 high                  high  2016-01-01            USD
# 24                 high                  high  2016-07-01            USD
# 25                 high                  high  2017-01-01            USD
# 26                 high                  high  2017-07-01            USD
# 27                 high                  high  2018-01-01            USD
# 28                 high                  high  2018-07-01            USD
# 29                 high                  high  2019-01-01            USD
# 30                 high                  high  2019-07-09            USD
# 31                 high                  high  2020-01-14            USD
# 32                 high                  high  2020-07-01            USD
# 33                 high                  high  2021-01-01            USD
# 34                 high                  high  2021-07-01            USD
# 35                 high                  high  2022-01-01            USD
# 36                 high                  high  2022-07-01            USD
#
#           country local_price dollar_ex dollar_price local_price_category  \
# 0   United States        2.24         1         2.24                  low
# 1   United States        2.24         1         2.24                  low
# 2   United States        2.35         1         2.35                  low
# 3   United States        2.46         1         2.46                  low
# 4   United States        2.47         1         2.47                  low
# 5   United States        2.58         1         2.58                  low
# 6   United States        2.67         1         2.67                  low
# 7   United States        2.78         1         2.78                  low
# 8   United States        2.89         1         2.89                  low
# 9   United States        3.00         1         3.00                  low
# 10  United States        3.21         1         3.21               medium
# 11  United States        3.43         1         3.43               medium
# 12  United States        3.43         1         3.43               medium
# 13  United States        3.53         1         3.53               medium
# 14  United States        3.64         1         3.64               medium
# 15  United States        3.81         1         3.81               medium
# 16  United States        3.96         1         3.96               medium
# 17  United States        4.03         1         4.03               medium
# 18  United States        4.18         1         4.18               medium
# 19  United States        4.24         1         4.24               medium
# 20  United States        4.29         1         4.29               medium
# 21  United States        4.29         1         4.29               medium
# 22  United States        4.29         1         4.29               medium
# 23  United States        4.29         1         4.29               medium
# 24  United States        4.50         1         4.50               medium
# 25  United States        4.50         1         4.50               medium
# 26  United States        4.50         1         4.50               medium
# 27  United States        4.61         1         4.61               medium
# 28  United States        4.62         1         4.62               medium
# 29  United States        4.71         1         4.71               medium
# 30  United States        4.71         1         4.71               medium
# 31  United States        4.82         1         4.82               medium
# 32  United States        4.82         1         4.82               medium
# 33  United States        4.89         1         4.89               medium
# 34  United States        4.93         1         4.93               medium
# 35  United States        5.04         1         5.04                 high
# 36  United States        5.15         1         5.15                 high
#
#    dollar_price_category
# 0                 medium
# 1                 medium
# 2                 medium
# 3                 medium
# 4                 medium
# 5                 medium
# 6                 medium
# 7                 medium
# 8                 medium
# 9                 medium
# 10                medium
# 11                medium
# 12                medium
# 13                medium
# 14                medium
# 15                medium
# 16                medium
# 17                  high
# 18                  high
# 19                  high
# 20                  high
# 21                  high
# 22                  high
# 23                  high
# 24                  high
# 25                  high
# 26                  high
# 27                  high
# 28                  high
# 29                  high
# 30                  high
# 31                  high
# 32                  high
# 33                  high
# 34                  high
# 35                  high
# 36                  high
#
# [37 rows x 25 columns]

# %% [markdown]
# ### Export to CSV or Excel
# Once your data is in a DataFrame, you can use Pandas' to_csv() or to_excel() methods to export the data to CSV or Excel format, respectively.
#
# <code>df.to_excel('data.xlsx', index=False)</code>  # Set index=False to exclude row numbers in the Excel file

# %%
# Export DataFrame to CSV
combined_df.to_csv('data.csv', index=True)  # Set index=True to include row numbers in the CSV

# %% [markdown]
# When you run the code to export your DataFrame to a CSV file using the name <code>'data.csv'</code>, that csv is created in the current working directory of your Python environment.
#
# The current working directory is typically the directory from which you launched your Python script or Jupyter Notebook. To find the location of the created CSV file, manually Navigate to the Directory:
#
# If you're working in Jupyter Notebook, you can also manually navigate to the directory where you expect the file to be saved. You can then look for the <code>'data.csv'</code> file in that directory.

# %%
# I want to import 3 separate DataFrames per currency as well.
# Export DataFrame to CSV
usd_df.to_csv('bigmac_usd_data.csv', index=True)  # Set index=True to include row numbers in the CSV
jpy_df.to_csv('bigmac_jpy_data.csv', index=True)
sek_df.to_csv('bigmac_sek_data.csv', index=True)
